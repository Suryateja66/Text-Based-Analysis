# %% [markdown]
# # Un-general dataset

# %%
# Importing the pandas library as pd
import pandas as pd

# %%
#importing data from csv file
file = "D:\\TEXT-BASED ANALYSIS CS-651-A\\un-general-debates-blueprint.csv"
# Reading the data from a CSV file into a pandas DataFrame and storing it in the variable 'df'.
df = pd.read_csv(file)
# Displaying the first 20 rows of the DataFrame 'df' to inspect the data.
df.head(20)
# Out:
#     session  year country                     country_name  \
# 0        25  1970     ALB                          Albania
# 1        25  1970     ARG                        Argentina
# 2        25  1970     AUS                        Australia
# 3        25  1970     AUT                          Austria
# 4        25  1970     BEL                          Belgium
# 5        25  1970     BLR                          Belarus
# 6        25  1970     BOL  Bolivia, Plurinational State of
# 7        25  1970     BRA                           Brazil
# 8        25  1970     CAN                           Canada
# 9        25  1970     CMR                         Cameroon
# 10       25  1970     COG                            Congo
# 11       25  1970     COL                         Colombia
# 12       25  1970     CRI                       Costa Rica
# 13       25  1970     CUB                             Cuba
# 14       25  1970     DOM               Dominican Republic
# ...

# %%
#This will open the file and then randomly pick 20% of the records.
#df = df.sample(frac=0.2)

# %% [markdown]
# ## Pre-Processing the Data from Dataset

# %%
# Accessing the column names of the DataFrame 'df' to retrieve information about the structure of the data.
df.columns
# Out:
# Index(['session', 'year', 'country', 'country_name', 'speaker', 'position',
#        'text'],
#       dtype='object')

# %%
# Checking the data types of each column in the DataFrame 'df' to understand how the data is stored.
df.dtypes
# Out:
# session          int64
# year             int64
# country         object
# country_name    object
# speaker         object
# position        object
# text            object
# dtype: object

# %%
# Displaying a concise summary of the DataFrame 'df', including the number of non-null values and data types of each column.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7507 entries, 0 to 7506
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   session       7507 non-null   int64
#  1   year          7507 non-null   int64
#  2   country       7507 non-null   object
#  3   country_name  7507 non-null   object
#  4   speaker       7480 non-null   object
#  5   position      4502 non-null   object
#  6   text          7507 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 410.7+ KB

# %%
# Generating descriptive statistics summary for the numerical columns in the DataFrame 'df', such as count, mean, standard deviation, minimum, and maximum values.
df.describe()
# Out:
#            session         year
# count  7507.000000  7507.000000
# mean     49.610763  1994.610763
# std      12.892155    12.892155
# min      25.000000  1970.000000
# 25%      39.000000  1984.000000
# 50%      51.000000  1996.000000
# 75%      61.000000  2006.000000
# max      70.000000  2015.000000

# %%
# Creating a new column 'length' in the DataFrame 'df' by computing the length of each string in the 'text' column.
df['length'] = df['text'].str.len()
# Generating descriptive statistics summary for the DataFrame 'df' after adding the 'length' column, including statistics for this new column.
df.describe()
# Out:
#            session         year        length
# count  7507.000000  7507.000000   7507.000000
# mean     49.610763  1994.610763  17967.281604
# std      12.892155    12.892155   7860.038463
# min      25.000000  1970.000000   2362.000000
# 25%      39.000000  1984.000000  12077.000000
# 50%      51.000000  1996.000000  16424.000000
# 75%      61.000000  2006.000000  22479.500000
# max      70.000000  2015.000000  72041.000000

# %%
#Stats about text fields
df.describe(include='O')
# Out:
#        country country_name        speaker                      position  \
# count     7507         7507           7480                          4502
# unique     199          199           5428                           113
# top        ALB      Albania  Seyoum Mesfin  Minister for Foreign Affairs
# freq        46           46             12                          1813
#
#                                                      text
# count                                                7507
# unique                                               7507
# top     33: May I first convey to our President the co...
# freq                                                    1

# %%
#checking number of missing data
df.isna().sum()
# Out:
# session            0
# year               0
# country            0
# country_name       0
# speaker           27
# position        3005
# text               0
# length             0
# dtype: int64

# %%
# Filling missing values in the 'speaker' column with the string 'unknown', and modifying the DataFrame in place.
df['speaker'].fillna('unknown', inplace=True)

# %%
# Filling missing values in the 'position' column of the DataFrame 'df' with the string 'unknown', and modifying the DataFrame in place.
df['position'].fillna('unknown', inplace=True)

# %%
# Counting the number of missing values+ in each column
df.isna().sum()
# Out:
# session         0
# year            0
# country         0
# country_name    0
# speaker         0
# position        0
# text            0
# length          0
# dtype: int64

# %%
# Converting the text in the 'speaker' column to uppercase for consistency.
df['speaker'] = df['speaker'].str.upper()
# Displaying the DataFrame 'df'
df
# Out:
#       session  year country  country_name                            speaker  \
# 0          25  1970     ALB       Albania                            MR. NAS
# 1          25  1970     ARG     Argentina                 MR. DE PABLO PARDO
# 2          25  1970     AUS     Australia                        MR. MCMAHON
# 3          25  1970     AUT       Austria                 MR. KIRCHSCHLAEGER
# 4          25  1970     BEL       Belgium                         MR. HARMEL
# ...       ...   ...     ...           ...                                ...
# 7502       70  2015     YEM         Yemen  MR. ABDRABUH MANSOUR HADI MANSOUR
# 7503       70  2015     YUG    Yugoslavia               MR. TOMISLAV NIKOLIĆ
# 7504       70  2015     ZAF  South Africa                         JACOB ZUMA
# 7505       70  2015     ZMB        Zambia             MR. EDGAR CHAGWA LUNGU
# 7506       70  2015     ZWE      Zimbabwe                      ROBERT MUGABE
#
# ...

# %%
# Converting the text in the 'position' column to uppercase for consistency.
df['position'] = df['position'].str.upper()
# Displaying the DataFrame 'df'
df
# Out:
#       session  year country  country_name                            speaker  \
# 0          25  1970     ALB       Albania                            MR. NAS
# 1          25  1970     ARG     Argentina                 MR. DE PABLO PARDO
# 2          25  1970     AUS     Australia                        MR. MCMAHON
# 3          25  1970     AUT       Austria                 MR. KIRCHSCHLAEGER
# 4          25  1970     BEL       Belgium                         MR. HARMEL
# ...       ...   ...     ...           ...                                ...
# 7502       70  2015     YEM         Yemen  MR. ABDRABUH MANSOUR HADI MANSOUR
# 7503       70  2015     YUG    Yugoslavia               MR. TOMISLAV NIKOLIĆ
# 7504       70  2015     ZAF  South Africa                         JACOB ZUMA
# 7505       70  2015     ZMB        Zambia             MR. EDGAR CHAGWA LUNGU
# 7506       70  2015     ZWE      Zimbabwe                      ROBERT MUGABE
#
# ...

# %%
# Converting the text in the 'text' column to uppercase for consistency.
df['text'] = df['text'].str.upper()
# Displaying the DataFrame 'df'
df
# Out:
#       session  year country  country_name                            speaker  \
# 0          25  1970     ALB       Albania                            MR. NAS
# 1          25  1970     ARG     Argentina                 MR. DE PABLO PARDO
# 2          25  1970     AUS     Australia                        MR. MCMAHON
# 3          25  1970     AUT       Austria                 MR. KIRCHSCHLAEGER
# 4          25  1970     BEL       Belgium                         MR. HARMEL
# ...       ...   ...     ...           ...                                ...
# 7502       70  2015     YEM         Yemen  MR. ABDRABUH MANSOUR HADI MANSOUR
# 7503       70  2015     YUG    Yugoslavia               MR. TOMISLAV NIKOLIĆ
# 7504       70  2015     ZAF  South Africa                         JACOB ZUMA
# 7505       70  2015     ZMB        Zambia             MR. EDGAR CHAGWA LUNGU
# 7506       70  2015     ZWE      Zimbabwe                      ROBERT MUGABE
#
# ...

# %%
# Selecting rows from the DataFrame 'df' where the 'speaker' column contains the substring 'BUSH'.
df[df['speaker'].str.contains('BUSH')]
# Out:
#       session  year country   country_name             speaker   position  \
# 2720       44  1989     USA  United States                BUSH  PRESIDENT
# 2876       45  1990     USA  United States         GEORGE BUSH    UNKNOWN
# 3038       46  1991     USA  United States         GEORGE BUSH  PRESIDENT
# 3207       47  1992     USA  United States     MR. GEORGE BUSH  PRESIDENT
# 4814       56  2001     USA  United States      GEORGE W. BUSH  PRESIDENT
# 5002       57  2002     USA  United States  MR. GEORGE W. BUSH  PRESIDENT
# 5191       58  2003     USA  United States      GEORGE W. BUSH  PRESIDENT
# 5382       59  2004     USA  United States   MR. GEORGE W BUSH  PRESIDENT
# 5760       61  2006     USA  United States  MR. GEORGE W. BUSH  PRESIDENT
# 5951       62  2007     USA  United States      GEORGE W. BUSH  PRESIDENT
# 6143       63  2008     USA  United States      GEORGE W. BUSH  PRESIDENT
#
#                                                    text  length
# ...

# %% [markdown]
# ## Data Visuailazation

# %%
# Plotting a graph of the values in the 'length' column
df['length'].plot()
# Out:
# <Axes: >

# %%
# Creating a box plot horizontally for the values in the 'length' column
df['length'].plot(kind='box', vert=False)
# Out:
# <Axes: >

# %%
# Creating a histogram plot for the values in the 'length' column of the DataFrame 'df' with 30 bins.
df['length'].plot(kind='hist', bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Importing the seaborn library for data visualization.
import seaborn as sns
# Creating a boolean mask to filter rows where the 'country' column contains specific countries.
where = df['country'].isin(['USA', 'FRA', 'GBR', 'CHN', 'RUS'])
 # Creating a categorical plot (box plot) showing the distribution of 'length' values for each country specified in the mask.
g = sns.catplot(data=df[where], x="country", y="length", kind='box')
# Adjusting the size of the plot.
g.fig.set_size_inches(10, 8) ###
# Out:
# C:\Users\tejas\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Pre-processing pipeline

# %%
# Importing the regex module for regular expression operations.
import regex as re

# %%
# Defining a Function to Pull Words
def tokenize(text):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)

# %%
testtext = "Let's defeat SARS-CoV-2 together in 2020! www.cdc.gov"
testtokens = tokenize(testtext)
print(testtokens)
# Out:
# ['Let', 's', 'defeat', 'SARS-CoV-2', 'together', 'in', 'www', 'cdc', 'gov']

# %% [markdown]
# ### Removing stop words

# %%
# Importing the Natural Language Toolkit (nltk) library.
import nltk
nltk.download('stopwords')
# Creating a set of English stopwords from the nltk stopwords corpus.
stopwords=set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# Out:
# {'herself', 'own', "hadn't", 'is', 'will', 'the', 'some', "it's", 'what', 'on', 'each', 'mightn', 'weren', 'we', 'theirs', 'ma', 'to', 'having', 'into', 'its', "mustn't", 'before', "hasn't", 'shouldn', 'hers', "weren't", 'with', 'as', "don't", 'mustn', 'too', 'and', 'i', 'them', 'needn', 'most', 'than', "won't", 'then', 'any', 'has', 'don', 'off', 'just', 'shan', 'that', 'now', 'both', 'hasn', 'against', 'her', "wasn't", 'your', 'themselves', 'below', 'did', 'wasn', 'here', 'ours', "that'll", 'myself', 'do', 't', 'ain', 'other', 'he', "mightn't", 'y', 'so', 'not', 'couldn', 're', 'these', 'you', 'under', 'only', "you'd", 'she', 'such', "needn't", 'were', 'out', 'have', 'am', 'or', 'be', 'didn', 'down', 'they', 'between', 'll', 'about', 'this', 'was', 'in', 'aren', "you're", 'who', 'won', 'had', 'which', 'itself', 'up', 'but', 'himself', 's', "aren't", 'until', 'while', 'all', 'during', 'been', 'whom', 'again', 'm', 'nor', 'their', 'does', 'an', "shouldn't", 'more', 'my', 'there', 'yo
# ...

# %%
# Function to remove stop words
def remove_stop(tokens):
    return[t for t in tokens if t.lower() not in stopwords]

# %%
cleantokens= remove_stop(testtokens)
print(cleantokens)
# Out:
# ['Let', 'defeat', 'SARS-CoV-2', 'together', 'www', 'cdc', 'gov']

# %% [markdown]
# ### Making "pipeline"

# %%
# Creating a Pipeline
pipeline = [str.lower, tokenize, remove_stop]

# %%
# Defining a Function to Run the Pipeline
def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens

# %%
# running pipeline
df['tokens'] = df['text'].apply(prepare, pipeline=pipeline)

# %%
# Count the tokens
df['num_tokens'] = df['tokens'].map(len)
df.tail()
# Out:
#       session  year country  country_name                            speaker  \
# 7502       70  2015     YEM         Yemen  Mr. Abdrabuh Mansour Hadi Mansour
# 7503       70  2015     YUG    Yugoslavia               Mr. Tomislav Nikolić
# 7504       70  2015     ZAF  South Africa                         Jacob Zuma
# 7505       70  2015     ZMB        Zambia             Mr. Edgar Chagwa Lungu
# 7506       70  2015     ZWE      Zimbabwe                      Robert Mugabe
#
#        position                                               text  length  \
# 7502  President  On behalf of the people and the Government of ...   10568
# 7503  President  \nSeventy years have passed since the establis...   25430
# 7504  President  I should like to congratulate the President an...   13662
# 7505  President  I would like to begin by thanking the Secretar...   14247
# 7506  President  Allow me at the outset to extend to Mr. Mogens...   11013
#
# ...

# %% [markdown]
# ## Word frequencyAnalysis

# %%
from collections import Counter

# %%
tokens = tokenize("She likes my cats and my cats like my sofa.")

# %%
# Counting number of times words are repeating Using "Counter"
testcount= Counter(tokens)

# %%
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 2, 'She': 1, 'likes': 1, 'and': 1, 'like': 1, 'sofa': 1})

# %%
# Adding new data to the current count
more_tokens = tokenize("She likes dogs and cats.")
testcount.update(more_tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 3, 'She': 2, 'likes': 2, 'and': 2, 'like': 1, 'sofa': 1, 'dogs': 1})

# %%
# Printing the 5 Words Repeated the Most
counter = Counter()
df['tokens'].map(counter.update)
print(counter.most_common(5))
# Out:
# [('nations', 124508), ('united', 120763), ('international', 117223), ('world', 89421), ('countries', 85734)]

# %%
# Putting the word frequency in its own dataframe for analysis 
freq_df = pd.DataFrame.from_dict(counter,orient='index', columns=['freq'])

# %%
freq_df = freq_df.query('freq >= 1')
freq_df.index.name = 'token'

# %%
# Sort and display
freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(10)
# Out:
#                  freq
# token
# nations        124508
# united         120763
# international  117223
# world           89421
# countries       85734
# peace           72625
# development     62632
# states          59713
# people          59338
# security        58425

# %%
#Statistical data
freq_df.describe()
# Out:
#                 freq
# count   68302.000000
# mean      162.686276
# std      1544.080072
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%        15.000000
# max    124508.000000

# %%
# Plotting a bar graph for most frequent words
ax = freq_df.head(15).plot(kind='barh', width=0.95, figsize=(12,8))
ax.invert_yaxis()
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words')
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %% [markdown]
# ## Word cloud Visualization

# %%
# Importing Worldcloud Package
from wordcloud import WordCloud
from matplotlib import pyplot as plt

# %%
text = df.query("year==2015 and country=='USA'")['text'].values[0]

# %%
plt.figure(figsize=(14, 7)) ###
wc = WordCloud(max_words=100, stopwords=stopwords)
wc.generate(text)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
# WordCloud visualization of Frequency
wc = WordCloud(background_color='white', width = 300, height=300, max_words=100, margin=2)  #BackGround Colour
wc.fit_words(freq_df['freq'].to_dict() )
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wc)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()
